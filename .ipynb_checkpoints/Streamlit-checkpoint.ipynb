# %%
import streamlit as st

import pandas as pd
import numpy as np
st.write("good")
# Out:
# 2024-08-08 11:45:32.739
# ...
#   command:
#
#     streamlit run C:\Users\abuda\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
